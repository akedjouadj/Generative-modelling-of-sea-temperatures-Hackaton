# %%
import pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data_train = pd.read_csv("data/df_train.csv")
position = np.load("data/position.npy")

# %%
position
# Out:
# array([ -3.242,  -4.992,  -0.292,   7.758,   1.608,  -0.842, -11.375,
#         -0.425,   2.875,   3.525,  -6.025,  11.425])

# %%
position = position.reshape((2, 6))

# %%
x = position[0, :]
y = position[1, :]

z = np.array(data_train.iloc[100,1:])

# %%
fig = plt.figure()

ax = fig.add_subplot(111,projection='3d')
ax.scatter(x,y,z, color='green')
